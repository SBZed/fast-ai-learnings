# %% [markdown]
# This notebook will contain the commands that will allow us to upload our work to github

# %%
# mount the google drive path
from google.colab import drive
drive.mount('/content/drive')
# %cd drive/My Drive/Colab Notebooks/Fast ai learnings

# %%
# First time
# !git init
# Out:
# Initialized empty Git repository in /content/drive/My Drive/Colab Notebooks/Fast ai learnings/.git/

# %%
import os
from getpass import getpass
import urllib

# user = input('User name: ')
password = getpass('Password: ')
password = urllib.parse.quote(password) # your password is converted into url format

# !git remote add origin https://{github_username}:{github_password}@github.com/{github_username}/{github_repo_name}.git
cmd_string = 'git remote add origin https://{0}:{1}@github.com/{0}/{2}.git'.format('SBZed', password, 'fast-ai-learnings')

os.system(cmd_string)
cmd_string, password = "", "" # removing the password from the variable
# Out:
# User name: SBZed
# Password: ··········
# Repo name: fast-ai-learnings

# %%
# !git config --global user.email 'zinjadsaurabh1997@gmail.com'
# !git config --global user.name 'SBZed'

# %%
# !git add .
# !git commit -m 'First commit'
# Out:
# [master 9aeaf51] First commit
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# !git push origin master
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address
